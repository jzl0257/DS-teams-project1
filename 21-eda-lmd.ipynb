# %% [markdown]
# # 21-eda-lmd

# %% [markdown]
# In this notebook, we will do exploratory data analysis on the cleaned data.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

lmd = pd.read_csv("LithicExperimentalData.csv")
lmd.head()
# Out:
#     Id   Img Id      Da      Dp  FWidth  FLength  FThickness  ELength  \
# 0  104  10708.0  30.893  38.251  36.878   46.822      10.179   44.168
# 1   19   5682.0  27.727  33.375  35.149   40.001       9.029   39.022
# 2   14   4826.0  26.726  36.061  30.199   46.332       8.025   47.365
# 3    1   2812.0  24.408  36.198  25.039   57.353       5.086   50.536
# 4   83   9441.0  22.869  29.388  24.044   39.820       4.390   38.568
#
#    EThickness  EWidth  ...  W/T Ratio  T/W Ratio  CHull Surface Area   Sieve  \
# 0      10.102  34.444  ...      3.623      0.276            3211.655  23.529
# 1       7.978  34.108  ...      3.893      0.257            2547.278  22.089
# 2       7.753  28.230  ...      3.763      0.266            2571.497  19.112
# 3       4.904  23.943  ...      4.923      0.203            2001.165  15.063
# 4       3.948  22.535  ...      5.477      0.183            1745.237  14.217
#
#    Angularity  Ellipticity  Fiber Length  Fiber Width  Krumbein Rnd  label
# ...

# %%
lmd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5299 entries, 0 to 5298
# Data columns (total 42 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Id                  5299 non-null   int64
#  1   Img Id              5299 non-null   float64
#  2   Da                  5299 non-null   float64
#  3   Dp                  5299 non-null   float64
#  4   FWidth              5299 non-null   float64
#  5   FLength             5299 non-null   float64
#  6   FThickness          5299 non-null   float64
#  7   ELength             5299 non-null   float64
#  8   EThickness          5299 non-null   float64
#  9   EWidth              5299 non-null   float64
#  10  Volume              5299 non-null   float64
#  11  Area                5299 non-null   float64
#  12  Perimeter           5299 non-null   float64
#  13  CHull  Area         5299 non-null   float64
#  14  CHull Perimeter     5299 non-null   float64
# ...

# %%
# area vs perimeter
sns.lmplot(x = 'Area',y = 'Perimeter', hue='label', data = lmd)
plt.title('Relationship between Area and Perimeter')
# Out:
# Text(0.5, 1.0, 'Relationship between Area and Perimeter')

# %%
# Dp
sns.stripplot(x = 'label',y = 'Dp', hue= "label", data = lmd, jitter=True)
sns.boxenplot(x = "label", y = "Dp",data = lmd)
plt.xlabel('Lithic')
plt.title('Dp: perimeter equivalent diameter')
# Out:
# Text(0.5, 1.0, 'Dp: perimeter equivalent diameter')

# %%
# Da
sns.stripplot(x = 'label',y = 'Da', hue= "label", data = lmd, jitter=True)
sns.boxenplot(x = "label", y = "Da",data = lmd)
plt.xlabel('Lithic')
plt.title('Da: area equivalent diameter')
# Out:
# Text(0.5, 1.0, 'Da: area equivalent diameter')

# %%
# Da vs Dp
sns.lmplot(x = 'Da',y = 'Dp', hue='label', data = lmd)
plt.title('Relationship between Da and Dp')
# Out:
# Text(0.5, 1.0, 'Relationship between Da and Dp')

# %%
plt.scatter(lmd["FWidth"],lmd["EWidth"],cmap = "coolwarm")
plt.xlabel('FWidth')
plt.ylabel('EWidth')
plt.title('FWidth vs EWidth')
# Out:
# Text(0.5, 1.0, 'FWidth vs EWidth')

# %%
plt.scatter(lmd["FLength"],lmd["ELength"],cmap = "coolwarm")
plt.xlabel('FLength')
plt.ylabel('ELength')
plt.title('FLength vs ELength')
# Out:
# Text(0.5, 1.0, 'FLength vs ELength')

# %%
plt.scatter(lmd["FThickness"],lmd["EThickness"],cmap = "coolwarm")
plt.xlabel('FThickness')
plt.ylabel('EThickness')
plt.title('FThickness vs EThickness')
# Out:
# Text(0.5, 1.0, 'FThickness vs EThickness')

# %%
plt.scatter(lmd["Concavity"],lmd["Convexity"],cmap = "coolwarm")
plt.xlabel('Concavity')
plt.ylabel('Convexity')
plt.title('Concavity vs Convexity')
# Out:
# Text(0.5, 1.0, 'Concavity vs Convexity')

# %%
plt.scatter(lmd["CHull  Area"],lmd["CHull Perimeter"],cmap = "coolwarm")
plt.xlabel('CHull  Area')
plt.ylabel('CHull Perimeter')
plt.title('CHull  Area vs CHull Perimeter')
# Out:
# Text(0.5, 1.0, 'CHull  Area vs CHull Perimeter')

# %%
plt.scatter(lmd["Circularity"],lmd["Roundness"],cmap = "coolwarm")
plt.xlabel('Circularity')
plt.ylabel('Roundness')
plt.title('Circularity vs Roundness')
# Out:
# Text(0.5, 1.0, 'Circularity vs Roundness')
